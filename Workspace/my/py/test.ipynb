# %%
# %pip install pymysql cryptography
# Out:
# Requirement already satisfied: pymysql in c:\users\human\appdata\local\programs\python\python311\lib\site-packages (1.1.1)
# Collecting cryptography
#   Downloading cryptography-45.0.4-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: cffi>=1.14 in c:\users\human\appdata\local\programs\python\python311\lib\site-packages (from cryptography) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\human\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.14->cryptography) (2.22)
# Downloading cryptography-45.0.4-cp311-abi3-win_amd64.whl (3.4 MB)
#    ---------------------------------------- 0.0/3.4 MB ? eta -:--:--
#    --------------------------- ------------ 2.4/3.4 MB 12.2 MB/s eta 0:00:01
#    ---------------------------------------- 3.4/3.4 MB 10.6 MB/s eta 0:00:00
# Installing collected packages: cryptography
# Successfully installed cryptography-45.0.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql

connection = pymysql.connect(
    host='192.168.0.158',
    user='humanda6',
    password='humanda6',
    database='univdb'
)

cur = connection.cursor()
cur.execute('''SHOW TABLES''')
tables = cur.fetchall()

print(type(tables[0][0]))
for table in tables:
    print(table)

for table in tables:
    print("\n\n")
    print(table[0])
    cur.execute(f'''DESC {table[0]}''')
    print(cur.fetchall())
    cur.execute(f'''SELECT * FROM {table[0]}''')
    for row in cur.fetchall():
        print(row)


cur.close()
connection.close()
# Out:
# <class 'str'>
# ('tbl_board',)
# ('tbl_comment',)
# ('tbl_member',)
# ('과목',)
# ('수강',)
# ('학생',)
# ('학생10',)
#
#
#
# tbl_board
# (('boardno', 'int', 'NO', 'PRI', None, 'auto_increment'), ('writer', 'varchar(20)', 'NO', 'MUL', None, ''), ('title', 'varchar(100)', 'NO', '', None, ''), ('content', 'varchar(10000)', 'NO', '', None, ''), ('writedate', 'datetime', 'YES', '', 'now()', 'DEFAULT_GENERATED'), ('modifydate', 'datetime', 'YES', '', 'now()', 'DEFAULT_GENERATED'), ('readcount', 'int', 'YES', '', '0', 'DEFAULT_GENERATED'), ('category', 'varchar(50)', 'NO', '', None, ''))
# (1, 'iamuserone', '수정된 게시글 1', '게시글 작성 연습입니다.', datetime.datetime(2025, 6, 16, 16, 11, 36), datetime.datetime(2025, 6, 16, 16, 13, 51), 0, 'free')
# (2, 'iamuserone', '게시글 연습 2', '게시글 작성 연습입니다.', datetime.datetime(2025, 6, 16, 16, 11, 36), datetime.datetime(2025, 6, 16, 16, 11, 36), 0, 'notice')
# (3, 'iamuserone', '게시글 연습 3', '게시글 작성 연습입니다.', datetime.datetime(2025, 6, 16, 16, 11, 36), datetime.datetime(2025, 6, 16, 16, 11, 36), 0, 'free')
#
#
#
# tbl_comment
# (('commentno', 'int', 'NO', 'PRI', None, 'auto_increment'), ('writer', 'varchar(20)', 'NO', 'MUL', None, ''), ('boardno', 'int', 'NO', 'MUL', None, ''), ('content', 'varchar(500)', 'NO', '', None, ''), ('writedate', 'datetime', 'YES', '', 'now()', 'DEFAULT_GENERATED'), ('modifydate', 'datetime', 'YES', '', 'now()', 'DEFAULT_GENERATED'))
# (1, 'iamusertwo', 1, '게시글 1에 대한 댓글', datetime.datetime(2025, 6, 16, 16, 12, 42), datetime.datetime(2025, 6, 16, 16, 12, 42))
# (2, 'iamusertwo', 2, '게시글 2에 대한 댓글', datetime.datetime(2025, 6, 16, 16, 12, 42), datetime.datetime(2025, 6, 16, 16, 12, 42))
# (3, 'iamusertwo', 3, '게시글 3에 대한 댓글', datetime.datetime(2025, 6, 16, 16, 12, 42), datetime.datetime(2025, 6, 16, 16, 12, 42))
#
#
#
# tbl_member
# (('memberid', 'varchar(20)', 'NO', 'PRI', None, ''), ('passwd', 'varchar(200)', 'NO', '', None, ''), ('email', 'varchar(50)', 'NO', 'UNI', None, ''), ('usertype', 'varchar(10)', 'YES', '', "_utf8mb4\\'user\\'", 'DEFAULT_GENERATED'), ('joindate', 'datetime', 'YES', '', 'now()', 'DEFAULT_GENERATED'), ('active', 'tinyint(1)', 'YES', '', 'true', 'DEFAULT_GENERATED'), ('usergrade', 'int', 'YES', '', None, ''))
# ('iamadminone', 'iamadminone', 'iamadminone@example.com', 'admin', datetime.datetime(2025, 6, 16, 16, 10, 59), 1, None)
# ('iamuserone', 'Pa$$word', 'iamuserone@naver.com', 'user', datetime.datetime(2025, 6, 16, 16, 10, 45), 1, None)
# ('iamuserthree', 'iamuserthree', 'iamuserthree@example.com', 'user', datetime.datetime(2025, 6, 16, 16, 10, 45), 1, None)
# ('iamusertwo', 'iamusertwo', 'iamusertwo@example.com', 'user', datetime.datetime(2025, 6, 16, 16, 10, 45), 0, None)
#
#
#
# 과목
# (('과목번호', 'char(4)', 'NO', 'PRI', None, ''), ('이름', 'varchar(20)', 'NO', '', None, ''), ('강의실', 'char(3)', 'NO', '', None, ''), ('개설학과', 'varchar(20)', 'NO', '', None, ''), ('시수', 'int', 'NO', '', None, ''))
# ('c001', '데이터베이스', '126', '컴퓨터', 3)
# ('c002', '정보보호', '137', '정보통신', 3)
# ('c003', '모바일웹', '128', '컴퓨터', 3)
# ('c004', '철학개론', '117', '철학', 2)
# ('c005', '전공글쓰기', '120', '교양학부', 1)
#
#
#
# 수강
# (('학번', 'char(6)', 'NO', 'PRI', None, ''), ('과목번호', 'char(4)', 'NO', 'PRI', None, ''), ('신청날짜', 'date', 'NO', '', None, ''), ('중간성적', 'int', 'YES', '', '0', ''), ('기말성적', 'int', 'YES', '', '0', ''), ('평가학점', 'char(1)', 'YES', '', None, ''))
# ('s001', 'c002', datetime.date(2019, 9, 3), 93, 98, 'A')
# ('s001', 'c004', datetime.date(2019, 3, 5), 82, 89, 'B')
# ('s001', 'c005', datetime.date(2020, 9, 3), 74, 79, 'C')
# ('s002', 'c001', datetime.date(2018, 3, 10), 31, 50, 'F')
# ('s003', 'c001', datetime.date(2019, 3, 3), 81, 82, 'B')
# ('s003', 'c002', datetime.date(2017, 9, 6), 85, 82, 'B')
# ('s004', 'c002', datetime.date(2018, 3, 5), 92, 95, 'A')
# ('s004', 'c003', datetime.date(2020, 9, 3), 91, 94, 'A')
# ('s004', 'c005', datetime.date(2019, 3, 3), 72, 78, 'C')
#
#
#
# 학생
# (('학번', 'char(4)', 'NO', 'PRI', None, ''), ('이름', 'varchar(20)', 'NO', '', None, ''), ('주소', 'varchar(50)', 'YES', '', '미정', ''), ('학년', 'int', 'NO', '', None, ''), ('나이', 'int', 'YES', '', None, ''), ('성별', 'char(1)', 'NO', '', None, ''), ('휴대폰번호', 'char(14)', 'YES', '', None, ''), ('소속학과', 'varchar(20)', 'YES', '', None, ''))
# ('s001', '김연아', '서울 서초', 4, 23, '여', '010-1111-2222', '컴퓨터')
# ('s002', '홍길동', '미정', 1, 26, '남', None, '통계')
# ('s003', '이승엽', None, 3, 30, '남', None, '정보통신')
# ('s004', '이영애', '경기 분당', 2, None, '여', '010-4444-5555', '정보통신')
# ('s005', '송윤아', '경기 분당', 4, 23, '여', '010-6666-7777', '컴퓨터')
# ('s006', '홍길동', '서울 종로', 2, 26, '남', '010-8888-9999', '컴퓨터')
# ('s007', '이은진', '경기 과천', 3, 23, '여', '010-2222-3333', '경영')
#
#
#
# 학생10
# (('학번', 'char(4)', 'NO', '', None, ''), ('이름', 'varchar(20)', 'NO', '', None, ''), ('주소', 'varchar(50)', 'YES', '', '미정', ''), ('학년', 'int', 'NO', '', None, ''), ('나이', 'int', 'YES', '', None, ''), ('성별', 'char(1)', 'NO', '', None, ''), ('휴대폰번호', 'char(14)', 'YES', '', None, ''), ('소속학과', 'varchar(20)', 'YES', '', None, ''))
# ('s001', '김연아', '서울 서초', 4, 23, '여', '010-1111-2222', '컴퓨터')
# ('s002', '홍길동', '미정', 1, 26, '남', None, '통계')
# ('s003', '이승엽', None, 3, 30, '남', None, '정보통신')
# ('s004', '이영애', '경기 분당', 2, None, '여', '010-4444-5555', '정보통신')
# ('s005', '송윤아', '경기 분당', 4, 23, '여', '010-6666-7777', '컴퓨터')
# ('s006', '홍길동', '서울 종로', 2, 26, '남', '010-8888-9999', '컴퓨터')
# ('s007', '이은진', '경기 과천', 3, 23, '여', '010-2222-3333', '경영')
